# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 128.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 162.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 108.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 133.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 137.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
## Write your code here
# Display column names
print("Column Names:")
print(df.columns.tolist())

# Display data types and non-null values
print("Data Types and Non-Null Counts:")
print(df.info())

# Display summary statistics for numerical columns
print("Summary Statistics (Numerical Columns):")
print(df.describe())

# Display the shape of the dataset
print(f"Dataset Shape: {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# Column Names:
# ...

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
## Write your code here
# Check total missing values per column
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100

# Combine and display
missing_data = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percent
}).sort_values(by='Missing Values', ascending=False)

# print("Missing Data Summary:")
# print(missing_data[missing_data['Missing Values'] > 0])
threshold = 0.6  # 60% missing
columns_to_drop = missing_data[missing_data['Percentage (%)'] > (threshold * 100)].index
df.drop(columns=columns_to_drop, inplace=True)
print(f"Dropped columns (>{int(threshold*100)}% missing): {list(columns_to_drop)}")
# Out:
# Dropped columns (>60% missing): ['AINextMuch less integrated', 'AINextLess integrated', 'AINextNo change', 'AINextMuch more integrated', 'EmbeddedAdmired', 'EmbeddedWantToWorkWith', 'EmbeddedHaveWorkedWith', 'ConvertedCompYearly', 'AIToolNot interested in Using', 'AINextMore integrated']

# %%
# Drop rows where essential columns are missing
essential_columns = ['Country', 'Employment', 'EdLevel']
df.dropna(subset=essential_columns, inplace=True)
print(f" Dropped rows with missing critical info in: {essential_columns}")
# Out:
#  Dropped rows with missing critical info in: ['Country', 'Employment', 'EdLevel']

# %%
# Convert 'YearsCodePro' to numeric, coercing errors to NaN
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['YearsCodePro'] = df['YearsCodePro'].fillna(df['YearsCodePro'].median())
df['RemoteWork'] = df['RemoteWork'].fillna(df['RemoteWork'].mode()[0])

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
## Write your code here
# Employment types distribution
print("Employment Type Distribution:")
print(df['Employment'].value_counts())
print("\n")

# Job satisfaction distribution
print(" Job Satisfaction Distribution:")
print(df['JobSat'].value_counts())
print("\n")

# Professional coding experience distribution
print(" Years of Professional Coding Experience:")
print(df['YearsCodePro'].value_counts())
# Out:
# Employment Type Distribution:
# Employment
# Employed, full-time                                                                                                                                                     35279
# Independent contractor, freelancer, or self-employed                                                                                                                     4430
# Student, full-time                                                                                                                                                       4162
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                 3259
# Not employed, but looking for work                                                                                                                                       2105
# ...

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
## Write your code here
# Remove missing values in JobSat
job_sat = df['JobSat'].dropna()

# Pie chart
job_sat.value_counts().plot.pie(autopct='%1.1f%%', figsize=(8, 8), startangle=90)
plt.title('Job Satisfaction Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
## Write your code here
# Split and explode both columns
df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].str.split(';')
df['LanguageWantToWorkWith'] = df['LanguageWantToWorkWith'].str.split(';')

worked = df.explode('LanguageHaveWorkedWith')
want = df.explode('LanguageWantToWorkWith')

# Count frequency
worked_langs = worked['LanguageHaveWorkedWith'].value_counts().head(10)
want_langs = want['LanguageWantToWorkWith'].value_counts().head(10)

# Combine and plot
language_df = pd.DataFrame({'Used': worked_langs, 'Want': want_langs})
language_df.plot(kind='bar', figsize=(12, 6))
plt.title('Top Programming Languages: Used vs. Want to Work With')
plt.ylabel('Number of Responses')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
## Write your code here
remote_region = pd.crosstab(df['Country'], df['RemoteWork'])

# Use top 10 countries only
top_countries = df['Country'].value_counts().head(10).index
remote_region = remote_region.loc[top_countries]

remote_region.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='viridis')
plt.title('Remote Work Preference by Region')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
plt.legend(title='Remote Work')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
## Write your code here
# Clean and convert data
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df['JobSatPoints_1'] = pd.to_numeric(df['JobSatPoints_1'], errors='coerce')

# Drop missing
cor_df = df[['YearsCodePro', 'JobSatPoints_1']].dropna()

# Correlation
corr = cor_df.corr(method='pearson')
print("Pearson Correlation:\n", corr)

# Scatter plot
sns.scatterplot(data=cor_df, x='YearsCodePro', y='JobSatPoints_1')
plt.title('Job Satisfaction vs. Years of Coding Experience')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Job Satisfaction (Points)')
plt.show()
# Out:
# Pearson Correlation:
#                  YearsCodePro  JobSatPoints_1
# YearsCodePro        1.000000       -0.031921
# JobSatPoints_1     -0.031921        1.000000

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
## Write your code here
cross_tab = pd.crosstab(df['EdLevel'], df['Employment'])

# Plot
cross_tab.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='plasma')
plt.title('Employment Type by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
# plt.legend(title='Employment Type')
plt.legend(title='Employment Type', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_362/168818148.py:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here
df.to_csv('cleaned_stackoverflow_survey.csv', index=False)
print("Cleaned dataset saved as 'cleaned_stackoverflow_survey.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_stackoverflow_survey.csv'

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
